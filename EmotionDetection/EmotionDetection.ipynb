# %%
import cv2

# %%
from deepface import DeepFace

# %%
img = cv2.imread(r"C:\Users\aswan\E2E ML Project\Computer_Vision_Projects\datasets\happyboy.jpg")
img.shape
# Out:
# (282, 425, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:03<00:00,  1.16it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 1.7014063614388452e-14,
#   'disgust': 3.361417784735695e-30,
#   'fear': 3.1290112017348216e-19,
#   'happy': 99.99997615814209,
#   'sad': 1.53669392270255e-14,
#   'surprise': 2.101973040069538e-08,
#   'neutral': 2.237168672536427e-05},
#  'dominant_emotion': 'happy',
#  'region': {'x': 177, 'y': 11, 'w': 223, 'h': 223},
#  'age': 24,
#  'gender': 'Man',
#  'race': {'asian': 4.170591632759073,
#   'indian': 2.4605070776049542,
#   'black': 0.1741362955837724,
#   'white': 40.97676819424439,
#   'middle eastern': 15.858636251606718,
#   'latino hispanic': 36.35936000104904},
#  'dominant_race': 'white'}

# %%
type(predictions)
# Out:
# dict

# %%
predictions['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = faceCascade.detectMultiScale(gray, 1.1, 4)

# %%
faces
# Out:
# array([[177,  11, 223, 223]])

# %%
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

#for inserting text on video 

cv2.putText(img,
                predictions['dominant_emotion'],
                (0, 50),
                font, 1,
                (0, 0, 255),
                2,
                cv2.LINE_4) ;

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread(r"C:\Users\aswan\E2E ML Project\Computer_Vision_Projects\datasets\sad_women.webp")

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  4.02it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 0.2966149421253766,
#   'disgust': 3.058663265121646e-05,
#   'fear': 0.20453463130650706,
#   'happy': 1.4587765643419796e-06,
#   'sad': 99.46894046479109,
#   'surprise': 9.435524924234925e-07,
#   'neutral': 0.02988116062469248},
#  'dominant_emotion': 'sad',
#  'region': {'x': 371, 'y': 36, 'w': 394, 'h': 394},
#  'age': 30,
#  'gender': 'Woman',
#  'race': {'asian': 99.27908773893641,
#   'indian': 0.21923432502057105,
#   'black': 0.000428184082976688,
#   'white': 0.10270240630298294,
#   'middle eastern': 0.0004251125372867821,
#   'latino hispanic': 0.3981255697831851},
#  'dominant_race': 'asian'}

# %%
img = cv2.imread(r"C:\Users\aswan\E2E ML Project\Computer_Vision_Projects\datasets\feared_man.jpg")

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  4.23it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 1.4370962195579744,
#   'disgust': 2.6000466588872626e-05,
#   'fear': 96.55981700899399,
#   'happy': 0.26877235211165523,
#   'sad': 0.0003022794866225223,
#   'surprise': 1.7339773271706906,
#   'neutral': 3.303320764490174e-11},
#  'dominant_emotion': 'fear',
#  'region': {'x': 96, 'y': 16, 'w': 224, 'h': 224},
#  'age': 29,
#  'gender': 'Man',
#  'race': {'asian': 8.162541428955878,
#   'indian': 11.855901739353046,
#   'black': 13.494297176259588,
#   'white': 20.540393623137096,
#   'middle eastern': 15.400736951871929,
#   'latino hispanic': 30.546130570538676},
#  'dominant_race': 'latino hispanic'}

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(1)

#check if the webcam is opened correctly 
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")

while True:
    ret,frame = cap.read() #read one image from a video

    result = DeepFace.analyze(frame, actions = ['emotion'])

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
    faces = faceCascade.detectMultiScale(gray,1.1,4)

    #draw a ractangle around the face
    for(x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    font = cv2.FONT_HERSHEY_SIMPLEX

    #For inserting text on video
        
    cv2.putText(frame,
                result['dominant_emotion'],
                (50, 50),
                font, 3,
                (0, 0, 255),
                2,
                cv2.LINE_4)
    cv2.imshow('Demo video',frame)

    if cv2.waitKey(2) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
